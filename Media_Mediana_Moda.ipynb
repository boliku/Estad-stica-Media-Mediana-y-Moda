# %% [markdown]
# # Estadística: Media, Mediana y Moda

# %% [markdown]
# ## Media
#
# La media es la suma del conjunto de valores dividida entre el número total de valores
#
# ![Media]("./media_arit.png")

# %% [markdown]
# ### Promedio de edades

# %%
edades = [20, 15, 41, 19, 62, 37, 14]
promedio = sum(edades)/len(edades)
print("Con funciones nativas:", promedio)


import numpy as np
edades = np.array([20, 15, 41, 19, 62, 37, 14])
promedio = edades.mean()
print("Con numpy:", promedio)

# Redondeo
print("Redondeado:", round(promedio), "años")
# Out:
# Con funciones nativas: 29.714285714285715
# Con numpy: 29.714285714285715
# Redondeado: 30 años

# %% [markdown]
# ## Ejercicio alumnos

# %%
import pandas as pd
df_alumnos = pd.read_csv("datos_alumnos.csv")
df_alumnos
# Out:
#                Nombre  Edad  Peso  Altura  Género
# 0      Roberto Alfaro    19    70    1.78  Hombre
# 1    Laura Bustamante    19    57    1.60   Mujer
# 2       Erick Estrada    20    65    1.74  Hombre
# 3     Maria Domínguez    20    52    1.60   Mujer
# 4        Jorge  Ortíz    20    60    1.70  Hombre
# 5        Rosa Jiménez    21    56    1.53   Mujer
# 6    Adolfo Hernández    22    70    1.73  Hombre
# 7      Adriana García    23    72    1.71   Mujer
# 8    Antonio Martínez    21    60    1.66  Hombre
# 9        Alicia López    19    62    1.65   Mujer
# 10   Enrique González    23    65    1.68  Hombre
# 11        Elena Pérez    24    59    1.61   Mujer
# 12  Enrique Rodríguez    21    67    1.69  Hombre
# 13       Lily Ramírez    23    55    1.50   Mujer
# 14        Roxana Cruz    20    50    1.56   Mujer
# 15     Paulina Flores    21    66    1.78   Mujer
# 16       Samuel Gómez    21    67    1.71  Hombre
# 17  Francisco  Huerta    21    71    1.75  Hombre
# 18    Sergio Trujillo    19    73    1.78  Hombre
# 19      Sofia Padilla    18    69    1.70   Mujer
# 20     Tania Alvarado    24    70    1.70   Mujer
# 21        Uriel Galán    25    76    1.79  Hombre
# 22        Vanesa Díaz    25    63    1.63   Mujer
# 23      Violeta Durán    24    49    1.56   Mujer
# 24    Valentín Acosta    23    80    1.82  Hombre

# %% [markdown]
# ### Promedio de las edades de todos los alumnos

# %%
prom_edades = df_alumnos["Edad"].mean()
print("Promedio de edades:", round(prom_edades), "años")
# Out:
# Promedio de edades: 21 años

# %% [markdown]
# ### Promedio de alturas de las estudiantes mujeres

# %%
df_alumnas = df_alumnos[df_alumnos["Género"]=="Mujer"]
df_alumnas
# Out:
#               Nombre  Edad  Peso  Altura Género
# 1   Laura Bustamante    19    57    1.60  Mujer
# 3    Maria Domínguez    20    52    1.60  Mujer
# 5       Rosa Jiménez    21    56    1.53  Mujer
# 7     Adriana García    23    72    1.71  Mujer
# 9       Alicia López    19    62    1.65  Mujer
# 11       Elena Pérez    24    59    1.61  Mujer
# 13      Lily Ramírez    23    55    1.50  Mujer
# 14       Roxana Cruz    20    50    1.56  Mujer
# 15    Paulina Flores    21    66    1.78  Mujer
# 19     Sofia Padilla    18    69    1.70  Mujer
# 20    Tania Alvarado    24    70    1.70  Mujer
# 22       Vanesa Díaz    25    63    1.63  Mujer
# 23     Violeta Durán    24    49    1.56  Mujer

# %%
promedio_altura_mujeres = df_alumnas["Altura"].mean()
print("Altura media de las mujeres:", round(promedio_altura_mujeres, 2), "metros")
# Out:
# Altura media de las mujeres: 1.63 metros

# %% [markdown]
# # Moda

# %% [markdown]
# ![moda.png](data:image/png;base64,...)

# %%
notas = [12, 20, 15, 18, 16, 15, 12, 15, 11, 15, 12, 18]
cantidad = []
for i in notas:
    cantidad.append(notas.count(i))
moda = notas[cantidad.index(max(cantidad))]
print("La moda es:", moda)
# Out:
# La moda es: 15

# %% [markdown]
# ## Ejercicio catálogo de Netflix

# %%
df_netflix = pd.read_csv("netflix_titles.csv")
df_netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#                                                 country          date_added  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                                NaN  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %% [markdown]
# ### ¿De qué año hay más películas y series en Netflix?

# %%
moda = df_netflix["release_year"].mode()
print("La moda es:", int(moda))
# Out:
# La moda es: 2018

# %% [markdown]
# ### ¿En qué país se han producido más películas y series?

# %%
moda = df_netflix["country"].mode()
print("La moda es:", moda)
# Out:
# La moda es: 0    United States
# Name: country, dtype: object

# %% [markdown]
# # Mediana

# %% [markdown]
# ![mediana.png](data:image/png;base64,...)

# %% [markdown]
# ### Mediana de edades

# %%
edades = [20, 15, 41, 19, 62, 37, 14, 1]
edades = sorted(edades)
print("Edades ordenadas:", edades)

if len(edades) % 2 != 0:
    mediana = edades[(len(edades)-1)//2]
else:
    mediana = (edades[len(edades)//2-1] + edades[len(edades)//2])/2
print("Con funciones nativas:", mediana)


import numpy as np
edades = np.array([20, 15, 41, 19, 62, 37, 14, 1])
mediana = np.median(edades)
print("Con numpy:", mediana)
# Out:
# Edades ordenadas: [1, 14, 15, 19, 20, 37, 41, 62]
# Con funciones nativas: 19.5
# Con numpy: 19.5

# %% [markdown]
# ## Ejercicio calificaciones de estudiantes

# %%
import pandas as pd
df_estudiantes = pd.read_csv("StudentsPerformance.csv")
df_estudiantes
# Out:
#      first_name   last_name  gender race/ethnicity  \
# 0         Laura      Bissot  female        group B
# 1         Mozhe    Atkinson  female        group C
# 2         James      Marlow  female        group B
# 3            TJ       Olson    male        group A
# 4         Jason      Mallin    male        group C
# 5       Michael      Rogers  female        group B
# 6            Ki         Gee  female        group B
# 7         Hazel  Philtanker    male        group B
# 8        Renske      Ladwig    male        group D
# 9       Stephen      Stiles  female        group B
# 10         John         Seo    male        group C
# 11       Joshua       Patel    male        group D
# 12       Trenna        Rajs  female        group B
# 13       Curtis      Davies    male        group A
# 14      Randall       Matos  female        group A
# 15        Peter      Vargas  female        group C
# 16         John     Russell    male        group C
# 17        Karen    Partners  female        group B
# 18      Alberto   Errazuriz    male        group C
# 19       Gerald   Cambrault  female        group C
# 20        Eleni     Zlotkey    male        group D
# 21        Peter      Tucker  female        group B
# 22        David   Bernstein    male        group D
# 23        Peter        Hall  female        group C
# 24  Christopher       Olsen    male        group D
# 25      Nanette   Cambrault    male        group A
# 26       Oliver     Tuvault    male        group B
# 27      Janette        King  female        group C
# 28      Patrick       Sully    male        group C
# 29        Allan      McEwen  female        group D
# 30      Lindsey       Smith  female        group D
# 31       Louise       Doran  female        group B
# 32       Sarath      Sewall  female        group E
# 33        Clara     Vishney    male        group D
# 34     Danielle      Greene    male        group E
# 35       Mattea     Marvins    male        group E
# 36        David         Lee  female        group D
# 37       Sundar        Ande  female        group D
# 38         Amit       Banda  female        group D
# 39         Lisa        Ozer    male        group B
# 40     Harrison       Bloom    male        group C
# 41       Tayler         Fox  female        group C
# 42      William       Smith  female        group B
# 43    Elizabeth       Bates    male        group B
# 44      Sundita       Kumar  female        group E
# 45        Ellen        Abel    male        group B
# 46       Alyssa      Hutton  female        group A
# 47     Jonathon      Taylor  female        group C
# 48         Jack  Livingston  female        group D
# 49    Kimberely       Grant    male        group C
#
#    parental level of education         lunch test preparation course  \
# 0            bachelor's degree      standard                    none
# 1                 some college      standard               completed
# 2              master's degree      standard                    none
# 3           associate's degree  free/reduced                    none
# 4                 some college      standard                    none
# 5           associate's degree      standard                    none
# 6                 some college      standard               completed
# 7                 some college  free/reduced                    none
# 8                  high school  free/reduced               completed
# 9                  high school  free/reduced                    none
# 10          associate's degree      standard                    none
# 11          associate's degree      standard                    none
# 12                 high school      standard                    none
# 13                some college      standard               completed
# 14             master's degree      standard                    none
# 15            some high school      standard                    none
# 16                 high school      standard                    none
# 17            some high school  free/reduced                    none
# 18             master's degree  free/reduced               completed
# 19          associate's degree  free/reduced                    none
# 20                 high school      standard                    none
# 21                some college  free/reduced               completed
# 22                some college      standard                    none
# 23            some high school      standard                    none
# 24           bachelor's degree  free/reduced               completed
# 25             master's degree  free/reduced                    none
# 26                some college      standard                    none
# 27           bachelor's degree      standard                    none
# 28                 high school      standard                    none
# 29             master's degree      standard                    none
# 30                some college      standard                    none
# 31                some college      standard                    none
# 32             master's degree  free/reduced                    none
# 33                some college      standard                    none
# 34                some college      standard                    none
# 35          associate's degree      standard               completed
# 36          associate's degree      standard                    none
# 37            some high school  free/reduced                    none
# 38          associate's degree  free/reduced               completed
# 39          associate's degree  free/reduced                    none
# 40          associate's degree  free/reduced                    none
# 41          associate's degree      standard                    none
# 42          associate's degree      standard                    none
# 43                some college  free/reduced               completed
# 44          associate's degree  free/reduced                    none
# 45          associate's degree      standard                    none
# 46          associate's degree      standard               completed
# 47                 high school      standard                    none
# 48          associate's degree  free/reduced               completed
# 49                 high school      standard               completed
#
#     math score  reading score  writing score
# 0           72             72             74
# 1           69             90             88
# 2           90             95             93
# 3           47             57             44
# 4           76             78             75
# 5           71             83             78
# 6           88             95             92
# 7           40             43             39
# 8           64             64             67
# 9           38             60             50
# 10          58             54             52
# 11          40             52             43
# 12          65             81             73
# 13          78             72             70
# 14          50             53             58
# 15          69             75             78
# 16          88             89             86
# 17          18             32             28
# 18          46             42             46
# 19          54             58             61
# 20          66             69             63
# 21          65             75             70
# 22          44             54             53
# 23          69             73             73
# 24          74             71             80
# 25          73             74             72
# 26          69             54             55
# 27          67             69             75
# 28          70             70             65
# 29          62             70             75
# 30          69             74             74
# 31          63             65             61
# 32          56             72             65
# 33          40             42             38
# 34          97             87             82
# 35          81             81             79
# 36          74             81             83
# 37          50             64             59
# 38          75             90             88
# 39          57             56             57
# 40          55             61             54
# 41          58             73             68
# 42          53             58             65
# 43          59             65             66
# 44          50             56             54
# 45          65             54             57
# 46          55             65             62
# 47          66             71             76
# 48          57             74             76
# 49          82             84             82

# %% [markdown]
# ### ¿Cuál es la mediana de las calificaciones en matemáticas?

# %%
mediana = df_estudiantes["math score"].median()
print("La mediana es:", mediana)
# Out:
# La mediana es: 65.0
